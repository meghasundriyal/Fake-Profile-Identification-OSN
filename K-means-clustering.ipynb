# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
dataset = pd.read_csv('data/twitter_dataset.csv', encoding = 'latin-1')
dataset.head()
# Out:
#     name_wt  statuses_count  followers_count  friends_count  favourites_count  \
# 0  0.857143            1211               24             63                 6
# 1  0.250000             313              101            173                48
# 2  0.411765             247               51            382                50
# 3  0.611111              41                3             36                 5
# 4  0.600000           12341              770           1417                 0
#
#    listed_count  label
# 0             6      0
# 1             0      0
# 2             4      0
# 3             0      0
# 4             8      1

# %%
features=[]
for attributes in dataset.columns:
    if attributes != 'label':
        features.append(attributes)
features
# Out:
# ['name_wt',
#  'statuses_count',
#  'followers_count',
#  'friends_count',
#  'favourites_count',
#  'listed_count']

# %%
X = np.array(dataset.drop(['label'], 1).astype(float))
# scaler = MinMaxScaler()
# X_scaled = scaler.fit_transform(X)

# %%
y = np.array(dataset['label'])

# %%
kmeans = KMeans(n_clusters=2,max_iter=1000,verbose=1) 
# kmeans.fit(X_scaled)
kmeans.fit(X)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 5436957891125.498
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 5436957891125.498
# center shift 0.000000e+00 within tolerance 3.461756e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 5436957891125.498
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 5436957891125.498
# center shift 0.000000e+00 within tolerance 3.461756e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 5436957891125.498
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 5436957891125.498
# center shift 0.000000e+00 within tolerance 3.461756e+04
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 6438003986629.357
# start iteration
# done sorting
# end inner loop
# ...

# %%
correct = 0
# for i in range(len(X)):
#     predict_me = np.array(X[i].astype(float))
#     predict_me = predict_me.reshape(-1, len(predict_me))
#     prediction = kmeans.predict(predict_me)
#     print(prediction)
#     if prediction[0] == y[i]:
# #         print(i)
#         correct += 1
predictions=kmeans.predict(X)
# print(predictions)
# print(correct/len(X))
print (predictions)
for i in range(len(predictions)):
    if predictions[i]==1:
        print (i)
# Out:
# [0 0 0 ... 0 0 0]
# 27

# %%
y[27]
# Out:
# 1

# %%
predict_me = np.array(X[6922].astype(float))
predict_me = predict_me.reshape(-1, len(predict_me))
predict_me.shape
# Out:
# (1, 6)

# %%
kmeans.predict(predict_me)[0]
# Out:
# 0

# %%
dataset
# Out:
#        name_wt  statuses_count  followers_count  friends_count  \
# 0     0.857143            1211               24             63
# 1     0.250000             313              101            173
# 2     0.411765             247               51            382
# 3     0.611111              41                3             36
# 4     0.600000           12341              770           1417
# 5     0.625000               4              134           1731
# 6     0.363636           17229              271            418
# 7     0.909091            1816              139            320
# 8     0.333333           14210              320            193
# 9     0.928571           41690             3174            772
# 10    0.923077            3278              204            459
# 11    0.133333             253             3491           3705
# 12    0.933333              62                6             35
# 13    0.923077              85              592           1695
# ...

# %%
X_scaled
# Out:
# array([[8.57142857e-01, 3.03087184e-03, 8.02253530e-06, 2.97324083e-04,
#         1.91110800e-05, 2.46426811e-04],
#        [2.50000000e-01, 7.83371501e-04, 3.37615027e-05, 8.16461371e-04,
#         1.52888640e-04, 0.00000000e+00],
#        [4.11764706e-01, 6.18187734e-04, 1.70478875e-05, 1.80282222e-03,
#         1.59259000e-04, 1.64284541e-04],
#        ...,
#        [5.00000000e-01, 6.88238165e-01, 3.28088267e-03, 1.03355515e-02,
#         1.27770310e-01, 1.56070314e-03],
#        [1.00000000e+00, 4.24549812e-01, 7.81528647e-04, 4.59200529e-03,
#         7.32591399e-04, 3.24461968e-03],
#        [1.00000000e+00, 2.50278435e-06, 4.34553996e-05, 3.64811931e-03,
#         0.00000000e+00, 0.00000000e+00]])
