# %%
import numpy as np
import pandas as pd

# %%
fusers_dataset = pd.read_csv('../data/fusers.csv', encoding = 'latin-1')
fusers_dataset.head()           #show first 5 rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-bd375b373d5f> in <module>
# ----> 1 fusers_dataset = pd.read_csv('../data/fusers.csv', encoding = 'latin-1')
#       2 fusers_dataset.head()           #show first 5 rows
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../data/fusers.csv' does not exist: b'../data/fusers.csv'

# %%
users_dataset = pd.read_csv('../data/users.csv', encoding = 'latin-1')
users_dataset.head()
# Out:
#         id              name screen_name  statuses_count  followers_count  \
# 0  3610511  Davide Dellacasa      braddd           20370             5470
# 1  5656162    Simone Economo       eKoeS            3131              506
# 2  5682702            tacone     tacone_            4024              264
# 3  6067292          alesaura    alesstar           40586              640
# 4  6015122            Angelo  PerDiletto            2016               62
#
#    friends_count  favourites_count  listed_count  \
# 0           2385               145            52
# 1            381                 9            40
# 2             87               323            16
# 3            622              1118            32
# 4             64                13             0
#
#                        created_at                                url  ...  \
# 0  Fri Apr 06 10:58:22 +0000 2007           http://braddd.tumblr.com  ...
# 1  Mon Apr 30 15:08:42 +0000 2007         http://www.lineheight.net/  ...
# 2  Tue May 01 11:53:40 +0000 2007               http://t.co/LKrl1dZE  ...
# 3  Tue May 15 16:55:16 +0000 2007     http://alesstar.wordpress.com/  ...
# 4  Sun May 13 19:52:00 +0000 2007  http://www.flickr.com/per_diletto  ...
#
#   profile_sidebar_fill_color  \
# 0                     FFF7CC
# 1                     DDEEF6
# 2                     000000
# 3                     95E8EC
# 4                     F6F6F6
#
#                         profile_background_image_url profile_background_color  \
# 0  http://a0.twimg.com/profile_background_images/...                   BADFCD
# 1    http://a0.twimg.com/images/themes/theme1/bg.png                   C0DEED
# 2  http://a0.twimg.com/profile_background_images/...                   1A1B1F
# 3    http://a0.twimg.com/images/themes/theme4/bg.gif                   0099B9
# 4   http://a0.twimg.com/images/themes/theme18/bg.gif                   ACDED6
#
#    profile_link_color  utc_offset  protected verified  \
# 0              FF0000      3600.0        NaN      NaN
# 1              0084B4      3600.0        NaN      NaN
# 2              2FC2EF      3600.0        NaN      NaN
# 3              0099B9      3600.0        NaN      NaN
# 4              038543      3600.0        NaN      NaN
#
#                                          description              updated  \
# 0  Founder of http://www.screenweek.it & http://w...  2015-02-14 10:54:49
# 1  BSc degree (cum laude) in Computer Engineering...  2015-02-14 10:54:49
# 2                             Cogito ergo bestemmio.  2015-02-14 10:54:49
# 3              Se la vita ti dÃ  sarde, scapocciale!  2015-02-14 10:54:49
# 4                                     Je me souviens  2015-02-14 10:54:49
#
#   dataset
# 0     E13
# 1     E13
# 2     E13
# 3     E13
# 4     E13
#
# [5 rows x 34 columns]

# %%
imp_list=['name','screen_name','statuses_count','followers_count','friends_count','favourites_count','listed_count']
users_dataset.drop(users_dataset.columns.difference(imp_list), axis = 1, inplace = True)

users_dataset.head()
# Out:
#                name screen_name  statuses_count  followers_count  \
# 0  Davide Dellacasa      braddd           20370             5470
# 1    Simone Economo       eKoeS            3131              506
# 2            tacone     tacone_            4024              264
# 3          alesaura    alesstar           40586              640
# 4            Angelo  PerDiletto            2016               62
#
#    friends_count  favourites_count  listed_count
# 0           2385               145            52
# 1            381                 9            40
# 2             87               323            16
# 3            622              1118            32
# 4             64                13             0

# %%
fusers_dataset.drop(fusers_dataset.columns.difference(imp_list), axis = 1, inplace = True)

fusers_dataset.head()
# Out:
#                  name   screen_name  statuses_count  followers_count  \
# 0        pirfectmoses  pirfectmoses              24                4
# 1            SAK Nair   bsknair1967             656               57
# 2              Deepak       dedjven            1234               15
# 3     Marcos Vinicius     BrowAlves             573               14
# 4  Shri Kant Kanaujia    kanaujiask             675               18
#
#    friends_count  favourites_count  listed_count
# 0            588                16             0
# 1            693               597             0
# 2            104              1150             0
# 3            227               530             0
# 4            519               653             0

# %%
'''
    label :  0  = genuine users
             1  = fake users
''' 
users_dataset['label'] = 0
fusers_dataset['label'] = 1

total_features = users_dataset.shape[1]
total_features
# Out:
# 8

# %%
users_dataset.head()
# Out:
#                name screen_name  statuses_count  followers_count  \
# 0  Davide Dellacasa      braddd           20370             5470
# 1    Simone Economo       eKoeS            3131              506
# 2            tacone     tacone_            4024              264
# 3          alesaura    alesstar           40586              640
# 4            Angelo  PerDiletto            2016               62
#
#    friends_count  favourites_count  listed_count  label
# 0           2385               145            52      0
# 1            381                 9            40      0
# 2             87               323            16      0
# 3            622              1118            32      0
# 4             64                13             0      0

# %%
fusers_dataset.head()
# Out:
#                  name   screen_name  statuses_count  followers_count  \
# 0        pirfectmoses  pirfectmoses              24                4
# 1            SAK Nair   bsknair1967             656               57
# 2              Deepak       dedjven            1234               15
# 3     Marcos Vinicius     BrowAlves             573               14
# 4  Shri Kant Kanaujia    kanaujiask             675               18
#
#    friends_count  favourites_count  listed_count  label
# 0            588                16             0      1
# 1            693               597             0      1
# 2            104              1150             0      1
# 3            227               530             0      1
# 4            519               653             0      1

# %%
dataset = pd.concat([users_dataset, fusers_dataset], axis = 0)
dataset.head()
# Out:
#                name screen_name  statuses_count  followers_count  \
# 0  Davide Dellacasa      braddd           20370             5470
# 1    Simone Economo       eKoeS            3131              506
# 2            tacone     tacone_            4024              264
# 3          alesaura    alesstar           40586              640
# 4            Angelo  PerDiletto            2016               62
#
#    friends_count  favourites_count  listed_count  label
# 0           2385               145            52      0
# 1            381                 9            40      0
# 2             87               323            16      0
# 3            622              1118            32      0
# 4             64                13             0      0

# %%
dataset.shape
# Out:
# (2818, 8)

# %%
dataset['name'] = dataset['name'].str.lower()
dataset['screen_name'] = dataset['screen_name'].str.lower()

# %%
dataset.head(10)
# Out:
#                name      screen_name  statuses_count  followers_count  \
# 0  davide dellacasa           braddd           20370             5470
# 1    simone economo            ekoes            3131              506
# 2            tacone          tacone_            4024              264
# 3          alesaura         alesstar           40586              640
# 4            angelo       perdiletto            2016               62
# 5  cristian paolini         crispaol            3603              138
# 6              tmpx             tmpx            1183              128
# 7              igor           igor99            6194             1062
# 8  marco massarotto  marcomassarotto           10962            23368
# 9    antonio parisi   personanormale           10947              760
#
#    friends_count  favourites_count  listed_count  label
# 0           2385               145            52      0
# 1            381                 9            40      0
# 2             87               323            16      0
# 3            622              1118            32      0
# 4             64                13             0      0
# 5            179                53             1      0
# 6            168                 2             5      0
# 7           1770               597             5      0
# 8            958               590           715      0
# 9            712               693            27      0

# %%
def maxSubsequence(screen_name, name): 
    # find the length of the strings 
    m = len(screen_name) 
    n = len(name) 
  
    # declaring the array for storing the dp values 
    L = [[None]*(n + 1) for i in range(m + 1)] 
  
    """Following steps build L[m + 1][n + 1] in bottom up fashion 
    Note: L[i][j] contains length of LCS of X[0..i-1] 
    and Y[0..j-1]"""
    for i in range(m + 1): 
        for j in range(n + 1): 
            if i == 0 or j == 0 : 
                L[i][j] = 0
            elif screen_name[i-1] == name[j-1]: 
                L[i][j] = L[i-1][j-1]+1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1]) 
  
    # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1] 
    return L[m][n]

# %%
#check for x in y
x = "ABCD"
y = "ABCABD" 
maxSubsequence(x, y)
# Out:
# 4

# %%
len(dataset)
# Out:
# 2818

# %%
#find max substring for every (name - screen_name) pair 
max_subsequence = {}
for row in range(len(dataset)):
    name = dataset['name'].iloc[row]
    screen_name = dataset['screen_name'].iloc[row]
    
    #find len of max subsequence of screen name in user name and add this len to a list
    max_subsequence[row] = maxSubsequence(screen_name, name)

# %%
#create a new column having length of max subsequence of screen name in name 
dataset['subseq']= max_subsequence.values()

# %%
dataset.head()
# Out:
#                name screen_name  statuses_count  followers_count  \
# 0  davide dellacasa      braddd           20370             5470
# 1    simone economo       ekoes            3131              506
# 2            tacone     tacone_            4024              264
# 3          alesaura    alesstar           40586              640
# 4            angelo  perdiletto            2016               62
#
#    friends_count  favourites_count  listed_count  label  subseq
# 0           2385               145            52      0       3
# 1            381                 9            40      0       2
# 2             87               323            16      0       6
# 3            622              1118            32      0       6
# 4             64                13             0      0       3

# %%
# we can see that names with longer length have more weights. we need to normalize this. [0-1]
# let us divide the len of subsequnce by the  length of the user name

def normaliseNameWeight(row):
    name = row['name']
    subseq = row['subseq']
    return (subseq/len(name))

dataset['name_wt'] = dataset.apply(normaliseNameWeight , axis=1)
dataset.head(10)
# Out:
#                name      screen_name  statuses_count  followers_count  \
# 0  davide dellacasa           braddd           20370             5470
# 1    simone economo            ekoes            3131              506
# 2            tacone          tacone_            4024              264
# 3          alesaura         alesstar           40586              640
# 4            angelo       perdiletto            2016               62
# 5  cristian paolini         crispaol            3603              138
# 6              tmpx             tmpx            1183              128
# 7              igor           igor99            6194             1062
# 8  marco massarotto  marcomassarotto           10962            23368
# 9    antonio parisi   personanormale           10947              760
#
#    friends_count  favourites_count  listed_count  label  subseq   name_wt
# 0           2385               145            52      0       3  0.187500
# 1            381                 9            40      0       2  0.142857
# 2             87               323            16      0       6  1.000000
# 3            622              1118            32      0       6  0.750000
# 4             64                13             0      0       3  0.500000
# 5            179                53             1      0       8  0.500000
# 6            168                 2             5      0       4  1.000000
# 7           1770               597             5      0       4  1.000000
# 8            958               590           715      0      15  0.937500
# 9            712               693            27      0       4  0.285714

# %%
drop_list=['name','screen_name','subseq']
dataset.drop(drop_list, axis = 1, inplace = True)

# %%
dataset.head()
# Out:
#    statuses_count  followers_count  friends_count  favourites_count  \
# 0           20370             5470           2385               145
# 1            3131              506            381                 9
# 2            4024              264             87               323
# 3           40586              640            622              1118
# 4            2016               62             64                13
#
#    listed_count  label   name_wt
# 0            52      0  0.187500
# 1            40      0  0.142857
# 2            16      0  1.000000
# 3            32      0  0.750000
# 4             0      0  0.500000

# %%
#reframe the columns of the dataset

features = ['name_wt','statuses_count', 'followers_count', 'friends_count','favourites_count','listed_count','label']

final_dataset = pd.DataFrame(dataset, columns = features)
final_dataset.head()
# Out:
#     name_wt  statuses_count  followers_count  friends_count  favourites_count  \
# 0  0.187500           20370             5470           2385               145
# 1  0.142857            3131              506            381                 9
# 2  1.000000            4024              264             87               323
# 3  0.750000           40586              640            622              1118
# 4  0.500000            2016               62             64                13
#
#    listed_count  label
# 0            52      0
# 1            40      0
# 2            16      0
# 3            32      0
# 4             0      0

# %%
export_csv = final_dataset.to_csv ('../data/facebook_dataset.csv', index = None, header=True)
