# %%
import numpy as np
import pandas as pd

# %%
fake_users_dataset_1= pd.read_csv('data/tagged dataset/A dataset of (i) genuine, (ii) traditional, and (iii) social spambot Twitter accounts/traditional_spambots_1.csv/users.csv')
fake_users_dataset_2 = pd.read_csv('data/tagged dataset/A dataset of (i) genuine, (ii) traditional, and (iii) social spambot Twitter accounts/traditional_spambots_2.csv/users.csv')
fake_users_dataset_3 = pd.read_csv('data/tagged dataset/A dataset of (i) genuine, (ii) traditional, and (iii) social spambot Twitter accounts/traditional_spambots_3.csv/users.csv')
fake_users_dataset_4 = pd.read_csv('data/tagged dataset/A dataset of (i) genuine, (ii) traditional, and (iii) social spambot Twitter accounts/traditional_spambots_4.csv/users.csv')

# %%
users_dataset = pd.read_csv('data/tagged dataset/A dataset of (i) genuine, (ii) traditional, and (iii) social spambot Twitter accounts/genuine_accounts.csv/users.csv')

# %%
fusers_dataset=pd.concat([fake_users_dataset_1,fake_users_dataset_2,fake_users_dataset_3,fake_users_dataset_4])

# %%
fusers_dataset.shape
# Out:
# (2631, 40)

# %%
users_dataset.shape
# Out:
# (3474, 42)

# %%
for attribute in fusers_dataset.columns:
    print(attribute)
# Out:
# id
# name
# screen_name
# statuses_count
# followers_count
# friends_count
# favourites_count
# listed_count
# url
# lang
# time_zone
# location
# default_profile
# default_profile_image
# geo_enabled
# profile_image_url
# profile_banner_url
# profile_use_background_image
# profile_background_image_url_https
# profile_text_color
# profile_image_url_https
# profile_sidebar_border_color
# profile_background_tile
# profile_sidebar_fill_color
# profile_background_image_url
# profile_background_color
# profile_link_color
# utc_offset
# is_translator
# follow_request_sent
# protected
# verified
# notifications
# description
# contributors_enabled
# following
# created_at
# timestamp
# crawled_at
# updated

# %%
imp_list=['name','screen_name','statuses_count','followers_count','friends_count','favourites_count','listed_count']
users_dataset.drop(users_dataset.columns.difference(imp_list), axis = 1, inplace = True)

users_dataset.head()
# Out:
#                 name      screen_name  statuses_count  followers_count  \
# 0    TASUKU HAYAKAWA         0918Bask            2177              208
# 1              ro_or         1120Roll            2660              330
# 2           bearclaw        14KBBrown            1254              166
# 3  pocahontas farida      wadespeters          202968             2248
# 4           Ms Kathy  191a5bd05da04dc              82               21
#
#    friends_count  favourites_count  listed_count
# 0            332               265             1
# 1            485              3972             5
# 2            177              1185             0
# 3            981             60304           101
# 4             79                 5             0

# %%
fusers_dataset.drop(fusers_dataset.columns.difference(imp_list), axis = 1, inplace = True)

fusers_dataset.head()
# Out:
#             name      screen_name  statuses_count  followers_count  \
# 0   Bhuvan Chand      tarunkjuyal            1259              837
# 1  Daniel Wagner     DanielWagner             770             3274
# 2    Andrew Lock       Andrewlock            1100            38849
# 3   Tim Thompson  yourinsaneworld            6497             5902
# 4        fxgenie          fxgenie            3203             2570
#
#    friends_count  favourites_count  listed_count
# 0           1978              3200             9
# 1           3595                 8            22
# 2          34504                41          1014
# 3           5496                 0            82
# 4           2638                 0             5

# %%
'''
    label :  0  = genuine users
             1  = fake users
''' 
users_dataset['label'] = 0
fusers_dataset['label'] = 1

total_features = users_dataset.shape[1]
total_features
# Out:
# 8

# %%
users_dataset.head()
# Out:
#                 name      screen_name  statuses_count  followers_count  \
# 0    TASUKU HAYAKAWA         0918Bask            2177              208
# 1              ro_or         1120Roll            2660              330
# 2           bearclaw        14KBBrown            1254              166
# 3  pocahontas farida      wadespeters          202968             2248
# 4           Ms Kathy  191a5bd05da04dc              82               21
#
#    friends_count  favourites_count  listed_count  label
# 0            332               265             1      0
# 1            485              3972             5      0
# 2            177              1185             0      0
# 3            981             60304           101      0
# 4             79                 5             0      0

# %%
fusers_dataset.head()
# Out:
#             name      screen_name  statuses_count  followers_count  \
# 0   Bhuvan Chand      tarunkjuyal            1259              837
# 1  Daniel Wagner     DanielWagner             770             3274
# 2    Andrew Lock       Andrewlock            1100            38849
# 3   Tim Thompson  yourinsaneworld            6497             5902
# 4        fxgenie          fxgenie            3203             2570
#
#    friends_count  favourites_count  listed_count  label
# 0           1978              3200             9      1
# 1           3595                 8            22      1
# 2          34504                41          1014      1
# 3           5496                 0            82      1
# 4           2638                 0             5      1

# %%
dataset = pd.concat([users_dataset, fusers_dataset], axis = 0)
dataset.head()
# Out:
#                 name      screen_name  statuses_count  followers_count  \
# 0    TASUKU HAYAKAWA         0918Bask            2177              208
# 1              ro_or         1120Roll            2660              330
# 2           bearclaw        14KBBrown            1254              166
# 3  pocahontas farida      wadespeters          202968             2248
# 4           Ms Kathy  191a5bd05da04dc              82               21
#
#    friends_count  favourites_count  listed_count  label
# 0            332               265             1      0
# 1            485              3972             5      0
# 2            177              1185             0      0
# 3            981             60304           101      0
# 4             79                 5             0      0

# %%
dataset.shape
# Out:
# (6105, 8)

# %%
dataset['name'] = dataset['name'].str.lower()
dataset['screen_name'] = dataset['screen_name'].str.lower()

# %%
dataset.head(10)
# Out:
#                 name      screen_name  statuses_count  followers_count  \
# 0    tasuku hayakawa         0918bask            2177              208
# 1              ro_or         1120roll            2660              330
# 2           bearclaw        14kbbrown            1254              166
# 3  pocahontas farida      wadespeters          202968             2248
# 4           ms kathy  191a5bd05da04dc              82               21
# 5                 jo     19_joanne_87           12915              641
# 6          ❄mckayla❄  1dniallprincess           13676             1042
# 7            giselle  1gisellepizarro           61294              561
# 8      nicole romany    1nicoleromany            4854              337
# 9       fallen angel         1_derika            2408              421
#
#    friends_count  favourites_count  listed_count  label
# 0            332               265             1      0
# 1            485              3972             5      0
# ...

# %%
def maxSubsequence(screen_name, name): 
    # find the length of the strings 
    m = len(screen_name) 
    n = len(name) 
  
    # declaring the array for storing the dp values 
    L = [[None]*(n + 1) for i in range(m + 1)] 
  
    """Following steps build L[m + 1][n + 1] in bottom up fashion 
    Note: L[i][j] contains length of LCS of X[0..i-1] 
    and Y[0..j-1]"""
    for i in range(m + 1): 
        for j in range(n + 1): 
            if i == 0 or j == 0 : 
                L[i][j] = 0
            elif screen_name[i-1] == name[j-1]: 
                L[i][j] = L[i-1][j-1]+1
            else: 
                L[i][j] = max(L[i-1][j], L[i][j-1]) 
  
    # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1] 
    return L[m][n]

# %%
#check for x in y
x = "ABCD"
y = "ABCABD" 
maxSubsequence(x, y)
# Out:
# 4

# %%
for name in dataset.screen_name:
    print(len(name))
# Out:
# 8
# 8
# 9
# 11
# 15
# 12
# 15
# 15
# 13
# 8
# 15
# 13
# 7
# 6
# 9
# 8
# 11
# 13
# 11
# 8
# 13
# 10
# 8
# 5
# 6
# 6
# 14
# 6
# 10
# 9
# 12
# 8
# 11
# 6
# 9
# 9
# 8
# 11
# 7
# 12
# 7
# 8
# 13
# 9
# 11
# 9
# 13
# 12
# 10
# 12
# 12
# 15
# 14
# 12
# 11
# 11
# 11
# 10
# 7
# 6
# 12
# 13
# 13
# 15
# 12
# 7
# 13
# 12
# 6
# 9
# 11
# 13
# 12
# 14
# 15
# 11
# 12
# 13
# 12
# 15
# 15
# 7
# 12
# 15
# 10
# 11
# 9
# 13
# 14
# 11
# 11
# 15
# 10
# 13
# 15
# 11
# 13
# 13
# 10
# 7
# 13
# 15
# 14
# 9
# 9
# 9
# 11
# 12
# 7
# 13
# 14
# 14
# 14
# 12
# 11
# 9
# 13
# 13
# 15
# 10
# 11
# 8
# 9
# 8
# 9
# 11
# 15
# 13
# 13
# 14
# 9
# 15
# 5
# 15
# 12
# 9
# 14
# 7
# 11
# 6
# 12
# 14
# 8
# 10
# 11
# 11
# 15
# 15
# 14
# 10
# 12
# 10
# 10
# 7
# 11
# 8
# 12
# 12
# 10
# 15
# 11
# 8
# 12
# 3
# 12
# 14
# 9
# 6
# 6
# 11
# 8
# 9
# 13
# 15
# 14
# 12
# 12
# 8
# 15
# 12
# 8
# 9
# 10
# 14
# 14
# 15
# 9
# 9
# 12
# 10
# 7
# 8
# 12
# 11
# 15
# 14
# 11
# 11
# 13
# 9
# 12
# 11
# 10
# 10
# 13
# 15
# 13
# 7
# 9
# 14
# 12
# 10
# 15
# ...

# %%
len(dataset)
# Out:
# 6105

# %%
#find max substring for every (name - screen_name) pair 
max_subsequence = {}
for row in range(len(dataset)):
    name = dataset['name'].iloc[row]
    screen_name = dataset['screen_name'].iloc[row]
    
    #find len of max subsequence of screen name in user name and add this len to a list
    max_subsequence[row] = maxSubsequence(screen_name, name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-040926b56ea7> in <module>
#       6
#       7     #find len of max subsequence of screen name in user name and add this len to a list
# ----> 8     max_subsequence[row] = maxSubsequence(screen_name, name)
#       9
#
# <ipython-input-27-8c251414796a> in maxSubsequence(screen_name, name)
#       2     # find the length of the strings
#       3     m = len(screen_name)
# ----> 4     n = len(name)
#       5
#       6     # declaring the array for storing the dp values
#
# TypeError: object of type 'float' has no len()
