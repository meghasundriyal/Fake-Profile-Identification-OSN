# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix, accuracy_score
import matplotlib.pyplot as plt

# %%
# function for plotting the accuracy and loss of the model
def plot(history):
    print()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
dataset = pd.read_csv('data/twitter_dataset.csv', encoding = 'latin-1')
dataset.head()         #show first 5 rows


features=[]
for attributes in dataset.columns:
    if attributes != 'label':
        features.append(attributes)

# data = dataset.as_matrix(columns = features)
data=dataset[features].values
#convert label column into 1D arrray

label = np.array(dataset['label'])


X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=0)

# %% [markdown]
# ## table hidden layer vs accuracy

# %%
#initialisations
max_iterations=10
number_of_hidden_layers=0
step=2


accuracy_list=[[0]*2 for _ in range(max_iterations)]
# define the keras model

for i in range(0,max_iterations):
    model = Sequential()
    # tanh and relu -check
    
    model.add(Dense(15, input_dim=len(features), activation='relu'))
    
    for j in range(number_of_hidden_layers):
        model.add(Dense(8, activation='relu'))
            
#     model.add(Dense(10, activation='relu'))
#     model.add(Dense(8, activation='relu'))
#     model.add(Dense(5, activation='relu'))
    
    model.add(Dense(1, activation='sigmoid'))

    # compile the keras model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    # fit the keras model on the dataset
    history=model.fit(X_train, y_train, epochs=150, batch_size=150,verbose=0)

    # evaluate the keras model
    _,accuracy = model.evaluate(X_test, y_test)
    
    print("i",i)
    accuracy_list[i][0]=number_of_hidden_layers
    accuracy_list[i][1]=accuracy
#     accuracy_list.append[number_of_hidden_layers , accuracy]
    
    number_of_hidden_layers+=step

#     print('Accuracy: %.2f' % (accuracy*100))
for i in range(len(accuracy_list)):
    print(accuracy_list[i][0],"\t",accuracy_list[i][1])

# %% [markdown]
# ## Activation Functions(tanh vs relu)

# %%
model1 = Sequential()
# tanh and relu -check
#three hidden layers
model1.add(Dense(15, input_dim=len(features), activation='relu'))
model1.add(Dense(4, activation='relu'))
model1.add(Dense(4, activation='relu'))
model1.add(Dense(4, activation='relu'))
model1.add(Dense(4, activation='relu'))
model1.add(Dense(4, activation='relu'))
model1.add(Dense(4, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history=model1.fit(X_train, y_train, epochs=150, batch_size=150,verbose=0)
# evaluate the keras model
_,accuracy = model1.evaluate(X_test, y_test)

print('Accuracy: %.2f' % (accuracy*100))
plot(history)

# %% [markdown]
# ## Number of Neurons in hidden layers

# %%
max_iterations=10
number_of_neurons=2
step=2


accuracy_list=[[0]*2 for _ in range(max_iterations)]
# define the keras model

for i in range(0,max_iterations):  
    model2 = Sequential()
    # tanh and relu -check
    #three hidden layers
    model2.add(Dense(15, input_dim=len(features), activation='relu'))
    model2.add(Dense(number_of_neurons, activation='relu'))
    model2.add(Dense(number_of_neurons, activation='relu'))
    model2.add(Dense(number_of_neurons, activation='relu'))
    model2.add(Dense(number_of_neurons, activation='relu'))
    model2.add(Dense(number_of_neurons, activation='relu'))
    model2.add(Dense(number_of_neurons, activation='relu'))
    model2.add(Dense(1, activation='sigmoid'))
    model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    history=model2.fit(X_train, y_train, epochs=150, batch_size=150,verbose=0)
    # evaluate the keras model
    _,accuracy = model2.evaluate(X_test, y_test)

    accuracy_list[i][0]=number_of_neurons
    accuracy_list[i][1]=accuracy*100
#     print('Accuracy: %.2f' % (accuracy*100))
    print(accuracy_list[i][1])
    number_of_neurons += step
    plot(history)
for i in range(len(accuracy_list)):
    print(accuracy_list[i][0],"\t",accuracy_list[i][1])

# %% [markdown]
# ## Number of Ephocs

# %%
max_iterations=100
number_of_ephocs=10
step=10


accuracy_list=[[0]*2 for _ in range(max_iterations)]
# define the keras model

for i in range(0,max_iterations):
    model1 = Sequential()

    model1.add(Dense(15, input_dim=len(features), activation='relu'))
    model1.add(Dense(10, activation='relu'))
    model1.add(Dense(10, activation='relu'))
    model1.add(Dense(10, activation='relu'))
    model1.add(Dense(10, activation='relu'))
    model1.add(Dense(10, activation='relu'))
    model1.add(Dense(10, activation='relu'))
    model1.add(Dense(1, activation='sigmoid'))
    model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    history=model1.fit(X_train, y_train, epochs=number_of_ephocs, batch_size=150,validation_split=0.30,verbose=0)
    # evaluate the keras model
    number_of_ephocs+=step
    _,accuracy = model1.evaluate(X_test, y_test)
    
    accuracy_list[i][0]=number_of_ephocs
    accuracy_list[i][1]=accuracy*100
    print("\n\nNo Of Ephocs: ",number_of_ephocs,'Accuracy: %.2f' % (accuracy*100))
    plot(history)
    number_of_ephocs+=step
# Out:
# 1389/1389 [==============================] - 0s 37us/step
#
#
# No Of Ephocs:  20 Accuracy: 81.86
# 1389/1389 [==============================] - 0s 37us/step
#
#
# No Of Ephocs:  40 Accuracy: 90.57
# 1389/1389 [==============================] - 0s 36us/step
#
#
# No Of Ephocs:  60 Accuracy: 74.15
# 1389/1389 [==============================] - 0s 31us/step
#
#
# No Of Ephocs:  80 Accuracy: 92.01
# 1389/1389 [==============================] - 0s 48us/step
#
#
# No Of Ephocs:  100 Accuracy: 93.09
# 1389/1389 [==============================] - 0s 33us/step
#
#
# No Of Ephocs:  120 Accuracy: 93.16
# 1389/1389 [==============================] - 0s 33us/step
#
#
# No Of Ephocs:  140 Accuracy: 94.24
# 1389/1389 [==============================] - 0s 92us/step
#
#
# No Of Ephocs:  160 Accuracy: 95.68
# 1389/1389 [==============================] - 0s 30us/step
#
#
# No Of Ephocs:  180 Accuracy: 94.60
# 1389/1389 [==============================] - 0s 37us/step
#
#
# No Of Ephocs:  200 Accuracy: 95.25
# 1389/1389 [==============================] - 0s 34us/step
#
#
# No Of Ephocs:  220 Accuracy: 95.25
# 1389/1389 [==============================] - 0s 67us/step
#
#
# No Of Ephocs:  240 Accuracy: 95.10
# 1389/1389 [==============================] - 0s 65us/step
#
#
# No Of Ephocs:  260 Accuracy: 93.95
# 1389/1389 [==============================] - 0s 54us/step
#
#
# No Of Ephocs:  280 Accuracy: 96.90
# 1389/1389 [==============================] - 0s 76us/step
#
#
# No Of Ephocs:  300 Accuracy: 93.45
# 1389/1389 [==============================] - 0s 30us/step
#
#
# No Of Ephocs:  320 Accuracy: 93.59
# 1389/1389 [==============================] - 0s 47us/step
#
#
# No Of Ephocs:  340 Accuracy: 96.40
# 1389/1389 [==============================] - 0s 21us/step
#
#
# No Of Ephocs:  360 Accuracy: 95.18
# 1389/1389 [==============================] - 0s 28us/step
#
#
# No Of Ephocs:  380 Accuracy: 96.04
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  400 Accuracy: 95.68
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  420 Accuracy: 94.02
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  440 Accuracy: 93.45
# 1389/1389 [==============================] - 0s 46us/step
#
#
# No Of Ephocs:  460 Accuracy: 95.82
# 1389/1389 [==============================] - 0s 46us/step
#
#
# No Of Ephocs:  480 Accuracy: 97.62
# 1389/1389 [==============================] - 0s 33us/step
#
#
# No Of Ephocs:  500 Accuracy: 97.48
# 1389/1389 [==============================] - 0s 32us/step
#
#
# No Of Ephocs:  520 Accuracy: 95.90
# 1389/1389 [==============================] - 0s 43us/step
#
#
# No Of Ephocs:  540 Accuracy: 97.48
# 1389/1389 [==============================] - 0s 45us/step
#
#
# No Of Ephocs:  560 Accuracy: 97.48
# 1389/1389 [==============================] - 0s 35us/step
#
#
# No Of Ephocs:  580 Accuracy: 97.91
# 1389/1389 [==============================] - 0s 29us/step
#
#
# No Of Ephocs:  600 Accuracy: 97.55
# 1389/1389 [==============================] - 0s 30us/step
#
#
# No Of Ephocs:  620 Accuracy: 94.96
# 1389/1389 [==============================] - 0s 29us/step
#
#
# No Of Ephocs:  640 Accuracy: 96.54
# 1389/1389 [==============================] - 0s 50us/step
#
#
# No Of Ephocs:  660 Accuracy: 96.11
# 1389/1389 [==============================] - 0s 21us/step
#
#
# No Of Ephocs:  680 Accuracy: 96.76
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  700 Accuracy: 96.33
# 1389/1389 [==============================] - 0s 31us/step
#
#
# No Of Ephocs:  720 Accuracy: 97.77
# 1389/1389 [==============================] - 0s 35us/step
#
#
# No Of Ephocs:  740 Accuracy: 97.62
# 1389/1389 [==============================] - 0s 21us/step
#
#
# No Of Ephocs:  760 Accuracy: 97.91
# 1389/1389 [==============================] - 0s 36us/step
#
#
# No Of Ephocs:  780 Accuracy: 98.56
# 1389/1389 [==============================] - 0s 25us/step
#
#
# No Of Ephocs:  800 Accuracy: 97.55
# 1389/1389 [==============================] - 0s 31us/step
#
#
# No Of Ephocs:  820 Accuracy: 97.91
# 1389/1389 [==============================] - 0s 36us/step
#
#
# No Of Ephocs:  840 Accuracy: 98.27
# 1389/1389 [==============================] - 0s 59us/step
#
#
# No Of Ephocs:  860 Accuracy: 97.12
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  880 Accuracy: 97.91
# 1389/1389 [==============================] - 0s 23us/step
#
#
# No Of Ephocs:  900 Accuracy: 98.27
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  920 Accuracy: 97.62
# 1389/1389 [==============================] - 0s 23us/step
#
#
# No Of Ephocs:  940 Accuracy: 98.34
# 1389/1389 [==============================] - 0s 21us/step
#
#
# No Of Ephocs:  960 Accuracy: 97.19
# 1389/1389 [==============================] - 0s 23us/step
#
#
# No Of Ephocs:  980 Accuracy: 97.84
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1000 Accuracy: 97.48
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1020 Accuracy: 97.41
# 1389/1389 [==============================] - 0s 24us/step
#
#
# No Of Ephocs:  1040 Accuracy: 97.26
# 1389/1389 [==============================] - 0s 30us/step
#
#
# No Of Ephocs:  1060 Accuracy: 96.90
# 1389/1389 [==============================] - 0s 30us/step
#
#
# No Of Ephocs:  1080 Accuracy: 97.98
# 1389/1389 [==============================] - 0s 33us/step
#
#
# No Of Ephocs:  1100 Accuracy: 97.77
# 1389/1389 [==============================] - 0s 33us/step
#
#
# No Of Ephocs:  1120 Accuracy: 98.27
# 1389/1389 [==============================] - 0s 59us/step
#
#
# No Of Ephocs:  1140 Accuracy: 97.77
# 1389/1389 [==============================] - 0s 31us/step
#
#
# No Of Ephocs:  1160 Accuracy: 98.20
# 1389/1389 [==============================] - 0s 35us/step
#
#
# No Of Ephocs:  1180 Accuracy: 97.41
# 1389/1389 [==============================] - 0s 41us/step
#
#
# No Of Ephocs:  1200 Accuracy: 95.25
# 1389/1389 [==============================] - 0s 38us/step
#
#
# No Of Ephocs:  1220 Accuracy: 97.84
# 1389/1389 [==============================] - 0s 45us/step
#
#
# No Of Ephocs:  1240 Accuracy: 93.38
# 1389/1389 [==============================] - 0s 32us/step
#
#
# No Of Ephocs:  1260 Accuracy: 98.34
# 1389/1389 [==============================] - 0s 34us/step
#
#
# No Of Ephocs:  1280 Accuracy: 92.66
# 1389/1389 [==============================] - 0s 35us/step
#
#
# No Of Ephocs:  1300 Accuracy: 97.98
# 1389/1389 [==============================] - 0s 29us/step
#
#
# No Of Ephocs:  1320 Accuracy: 96.83
# 1389/1389 [==============================] - 0s 37us/step
#
#
# No Of Ephocs:  1340 Accuracy: 97.48
# 1389/1389 [==============================] - 0s 54us/step
#
#
# No Of Ephocs:  1360 Accuracy: 97.84
# 1389/1389 [==============================] - 0s 39us/step
#
#
# No Of Ephocs:  1380 Accuracy: 97.70
# 1389/1389 [==============================] - 0s 34us/step
#
#
# No Of Ephocs:  1400 Accuracy: 97.98
# 1389/1389 [==============================] - 0s 33us/step
#
#
# No Of Ephocs:  1420 Accuracy: 97.77
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1440 Accuracy: 98.13
# 1389/1389 [==============================] - 0s 36us/step
#
#
# No Of Ephocs:  1460 Accuracy: 97.84
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1480 Accuracy: 98.27
# 1389/1389 [==============================] - 0s 23us/step
#
#
# No Of Ephocs:  1500 Accuracy: 97.98
# 1389/1389 [==============================] - 0s 21us/step
#
#
# No Of Ephocs:  1520 Accuracy: 98.20
# 1389/1389 [==============================] - 0s 23us/step
#
#
# No Of Ephocs:  1540 Accuracy: 98.20
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1560 Accuracy: 98.13
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1580 Accuracy: 97.84
# 1389/1389 [==============================] - 0s 23us/step
#
#
# No Of Ephocs:  1600 Accuracy: 98.42
# 1389/1389 [==============================] - 0s 32us/step
#
#
# No Of Ephocs:  1620 Accuracy: 97.84
# 1389/1389 [==============================] - 0s 30us/step
#
#
# No Of Ephocs:  1640 Accuracy: 98.27
# 1389/1389 [==============================] - 0s 48us/step
#
#
# No Of Ephocs:  1660 Accuracy: 98.34
# 1389/1389 [==============================] - 0s 38us/step
#
#
# No Of Ephocs:  1680 Accuracy: 97.98
# 1389/1389 [==============================] - 0s 34us/step
#
#
# No Of Ephocs:  1700 Accuracy: 98.20
# 1389/1389 [==============================] - 0s 37us/step
#
#
# No Of Ephocs:  1720 Accuracy: 97.91
# 1389/1389 [==============================] - 0s 35us/step
#
#
# No Of Ephocs:  1740 Accuracy: 97.77
# 1389/1389 [==============================] - 0s 26us/step
#
#
# No Of Ephocs:  1760 Accuracy: 98.13
# 1389/1389 [==============================] - 0s 36us/step
#
#
# No Of Ephocs:  1780 Accuracy: 98.13
# 1389/1389 [==============================] - 0s 21us/step
#
#
# No Of Ephocs:  1800 Accuracy: 98.34
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1820 Accuracy: 98.13
# 1389/1389 [==============================] - 0s 21us/step
#
#
# No Of Ephocs:  1840 Accuracy: 97.91
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1860 Accuracy: 98.49
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1880 Accuracy: 97.41
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1900 Accuracy: 98.20
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1920 Accuracy: 98.42
# 1389/1389 [==============================] - 0s 90us/step
#
#
# No Of Ephocs:  1940 Accuracy: 98.20
# 1389/1389 [==============================] - 0s 23us/step
#
#
# No Of Ephocs:  1960 Accuracy: 97.91
# 1389/1389 [==============================] - 0s 22us/step
#
#
# No Of Ephocs:  1980 Accuracy: 97.84
# 1389/1389 [==============================] - 0s 35us/step
#
#
# No Of Ephocs:  2000 Accuracy: 98.49

# %%
for i in range(len(accuracy_list)):
    print(accuracy_list[i][0],"\t",accuracy_list[i][1])
# Out:
# 20 	 81.85744881629944
# 40 	 90.56875705718994
# 60 	 74.15406703948975
# 80 	 92.00863838195801
# 100 	 93.08855533599854
# 120 	 93.16054582595825
# 140 	 94.24046277999878
# 160 	 95.68034410476685
# 180 	 94.6004331111908
# 200 	 95.24837732315063
# 220 	 95.24837732315063
# 240 	 95.10439038276672
# 260 	 93.95248293876648
# 280 	 96.90424799919128
# 300 	 93.44852566719055
# 320 	 93.59251260757446
# 340 	 96.40029072761536
# 360 	 95.17638683319092
# 380 	 96.04031443595886
# 400 	 95.68034410476685
# 420 	 94.02447938919067
# 440 	 93.44852566719055
# 460 	 95.82433700561523
# 480 	 97.62418866157532
# 500 	 97.4802017211914
# 520 	 95.89632749557495
# 540 	 97.4802017211914
# 560 	 97.4802017211914
# 580 	 97.91216850280762
# 600 	 97.5521981716156
# 620 	 94.96040344238281
# 640 	 96.54427766799927
# 660 	 96.11231088638306
# 680 	 96.76026105880737
# 700 	 96.32829427719116
# 720 	 97.76817560195923
# 740 	 97.62418866157532
# 760 	 97.91216850280762
# 780 	 98.56011271476746
# 800 	 97.5521981716156
# 820 	 97.91216850280762
# 840 	 98.27213883399963
# 860 	 97.12023138999939
# 880 	 97.91216850280762
# 900 	 98.27213883399963
# 920 	 97.62418866157532
# 940 	 98.34413528442383
# 960 	 97.1922218799591
# 980 	 97.84017205238342
# 1000 	 97.4802017211914
# 1020 	 97.40820527076721
# 1040 	 97.2642183303833
# 1060 	 96.90424799919128
# 1080 	 97.98415899276733
# 1100 	 97.76817560195923
# 1120 	 98.27213883399963
# 1140 	 97.76817560195923
# 1160 	 98.20014238357544
# 1180 	 97.40820527076721
# 1200 	 95.24837732315063
# 1220 	 97.84017205238342
# 1240 	 93.37652921676636
# 1260 	 98.34413528442383
# 1280 	 92.65658855438232
# 1300 	 97.98415899276733
# 1320 	 96.83225154876709
# 1340 	 97.4802017211914
# 1360 	 97.84017205238342
# 1380 	 97.69618511199951
# 1400 	 97.98415899276733
# 1420 	 97.76817560195923
# 1440 	 98.12815189361572
# 1460 	 97.84017205238342
# 1480 	 98.27213883399963
# 1500 	 97.98415899276733
# 1520 	 98.20014238357544
# 1540 	 98.20014238357544
# 1560 	 98.12815189361572
# 1580 	 97.84017205238342
# 1600 	 98.41612577438354
# 1620 	 97.84017205238342
# 1640 	 98.27213883399963
# 1660 	 98.34413528442383
# 1680 	 97.98415899276733
# 1700 	 98.20014238357544
# 1720 	 97.91216850280762
# 1740 	 97.76817560195923
# 1760 	 98.12815189361572
# 1780 	 98.12815189361572
# 1800 	 98.34413528442383
# 1820 	 98.12815189361572
# 1840 	 97.91216850280762
# 1860 	 98.48812222480774
# 1880 	 97.40820527076721
# 1900 	 98.20014238357544
# 1920 	 98.41612577438354
# 1940 	 98.20014238357544
# 1960 	 97.91216850280762
# 1980 	 97.84017205238342
# 2000 	 98.48812222480774
